# %% [markdown]
# # Dataset generation notebook for COBOL -BR JSON automation

# %% [markdown]
# ## Import the required libraries

# %%
import subprocess

# %%
try:
    import pathtlib
except ImportError:
    print("Library not found. Installing...")
    try:
        subprocess.check_call(["pip", "install", "pathlib"])
        print("Library installed successfully.")
        import pathlib  # Now try importing again
    except Exception as e:
        print(f"Failed to install library: {e}")
# Out:
# Library not found. Installing...
# Library installed successfully.

# %%
try:
    import textwrap
except ImportError:
    print("Library not found. Installing...")
    try:
        subprocess.check_call(["pip", "install", "textwrap"])
        print("Library installed successfully.")
        import textwrap  # Now try importing again
    except Exception as e:
        print(f"Failed to install library: {e}")

# %%
try:
    import google.generativeai as genai
except ImportError:
    print("Library not found. Installing...")
    try:
        subprocess.check_call(["pip", "install", "google.generativeai"])
        print("Library installed successfully.")
        import google.generativeai as genai  # Now try importing again
    except Exception as e:
        print(f"Failed to install library: {e}")

# %%
from IPython.display import display
from IPython.display import Markdown
import time
import json
import pandas as pd

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\chira\appdata\local\programs\python\python310\lib\site-packages (4.29.2)
# Requirement already satisfied: filelock in c:\users\chira\appdata\local\programs\python\python310\lib\site-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in c:\users\chira\appdata\local\programs\python\python310\lib\site-packages (from transformers) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\chira\appdata\local\programs\python\python310\lib\site-packages (from transformers) (1.23.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\chira\appdata\local\programs\python\python310\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\chira\appdata\local\programs\python\python310\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\chira\appdata\local\programs\python\python310\lib\site-packages (from transformers) (2022.3.2)
# Requirement already satisfied: requests in c:\users\chira\appdata\local\programs\python\python310\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\chira\appdata\local\programs\python\python310\lib\site-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\chira\appdata\local\programs\python\python310\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in c:\users\chira\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\chira\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\chira\appdata\local\programs\python\python310\lib\site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: colorama in c:\users\chira\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.27->transformers) (0.4.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\chira\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chira\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\chira\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chira\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers) (2022.9.24)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\chira\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\chira\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from transformers import LlamaTokenizer

# %%
directory_path_CBL = "C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files"
directory_path_COB = "C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/ALL_COB"

geminiApiKey = 'AIzaSyABQ7adBwnlHTLO8JgIh3w33kqihU5LjQY'

with open('codeSystemMessage.txt','r') as file:
    code_systemMessage = file.read()

code_systemMessage
# Out:
# '# you take a COBOL program and create Business Rules for it.\n# you are GREAT at extracting the business rules from all business variables in the code.\n# A business rules are defined as everyday business logics that get coded into the program.\n# There is a clear distinction between a business rule and a trivial validation. A business rule MAY CHANGE over time, but a trivial validation does not.\n# DO NOT INCLUDE ANYTHING OTHER THAN THE JSON in your response.\n# You  must generate multiple business rules from the given program.\n# mention the business rule id in your response.\n# your answer MUST be a valid json format, with each property of a business rule clearly listed.\n# any \'\\n\' in the text fields MUST be \'\\\\n\' so that when reading it later on, we won\'t run into any issues\n\n# example input and output with a simple COBOL file\n# Input:\n       IDENTIFICATION DIVISION.\n       PROGRAM-ID. EXAMPLE.\n       DATA DIVISION.\n       WORKING-STORAGE SECTION.\n       77  NUM         PICTURE 99.\n       77  QUOTIENT    PICTURE 99.\n       77  REMAIN      PICTURE 9.\n       PROCEDURE DIVISION.\n           ACCEPT NUM.\n           DIVIDE NUM BY 2 GIVING QUOTIENT REMAINDER REMAIN.\n           IF REMAIN = 0\n                   DISPLAY NUM \' IS EVEN\'\n           ELSE\n                   DISPLAY  NUM \' IS ODD\'\n           END-IF.\n           STOP RUN.\n# Output:\n{\n  "id": "BR-001",  "description": "A number is even if the remainder after dividing by 2 is 0, otherwise it is odd.",\n  "condition": "NUM DIV 2",\n  "output": {\n    "even": "NUM is EVEN",\n    "odd": "NUM is ODD"\n  }\n}\n# end of examples.\n\n# this is the COBOL code:'

# %% [markdown]
# ## Get the paths of all CBL files

# %%
import glob

# %%
def get_cbl_files(directory):
    cbl_files = glob.glob(directory+ '/*/*.cbl', recursive=True)
    return cbl_files

cbl_files = get_cbl_files(directory_path_CBL)

len(cbl_files)
# Out:
# 562

# %%
with open(cbl_files[4], 'r') as file:
    file_content = file.read()
print(file_content)
# Out:
#       $set sourceformat"free"
#        program-id. CS00001S.
#       *>=================================================================================
#       *>
#       *>                        Gerenciador de Chamadas Assincronas
#       *>
#       *>=================================================================================
#        environment division.
#        configuration section.
#             special-names. decimal-point is comma.
#
#
#       *>=================================================================================
#        data division.
#
#       *>=================================================================================
#        working-storage section.
#
#        78   c-versao                               value "a".
#        78   c-este-programa                        value "CS00001S".
#
#       *>=================================================================================
#        linkage section.
#
#        copy CSL00900.cpy.
#
#       *>=================================================================================
#        procedure division using lnk-par.
#
#       *>=================================================================================
#
#        0000-controle section.
#             perform 1000-inicializacao
#             perform 2000-processamento
#             perform 3000-finalizacao.
#        0000-saida.
#             exit program
#             stop run
#        exit.
#
#       *>=================================================================================
#        1000-inicializacao section.
#
#
#        exit.
#
#       *>=================================================================================
#        2000-processamento section.
#
#
#        exit.
#
#       *>=================================================================================
#        3000-finalizacao section.
#
#
#        exit.

# %% [markdown]
# ## Count all tokens in a program

# %%
# !pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in c:\users\chira\appdata\local\programs\python\python310\lib\site-packages (0.2.0)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\chira\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\chira\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
file_content =""
for doc in cbl_files:
    with open(doc, 'r',encoding='latin-1') as file:
        file_content = file_content + file.read()

# %%
len(file_content)
# Out:
# 6274080

# %%
genai.configure(api_key=geminiApiKey)
model = genai.GenerativeModel('gemini-pro')

def get_raw_text_gemini(file_content,systemMessage):
    response = model.generate_content(code_systemMessage+"\n\n"+file_content
                                    ,generation_config=genai.types.GenerationConfig(max_output_tokens=5000))
    # candidates=response.candidates[0].content.parts[0].text
#     print(response.prompt_feedback)
    return(response.text)

# %%
with open(cbl_files[7], 'r') as file:
    file_content = file.read()
    
# generate question and answer pairs
raw_response=get_raw_text_gemini(file_content,code_systemMessage)
raw_response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 with open(cbl_files[7], 'r') as file:
#       2     file_content = file.read()
#       4 # generate question and answer pairs
#
# NameError: name 'cbl_files' is not defined

# %%
print(file_content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 print(file_content)
#
# NameError: name 'file_content' is not defined

# %%
print(raw_response)
# Out:
# {
#   "id": "BR-001",
#   "description": "If the user is not a master user, the program checks if the user has access to the selected module.",
#   "condition": "not lnk-login-master",
#   "output": {
#     "access_granted": "set ws-usuario-acesso             to true",
#     "access_denied": "set ws-usuario-sem-acesso              to true"
#   }
# }

# %%
cbl_files[133]
# Out:
# 'C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\\cicsdev_cics-async-api-redbooks\\WEBHOME.cbl'

# %%
import os

def read_cobol_file(file_path):
    # Check file size
    file_size = os.path.getsize(file_path)
    if file_size < 10240:  # 10KB in bytes
        with open(file_path, 'r', encoding='latin-1') as file:
            return file.read()
    else:
        return None  # Skip files larger than 10KB

data_list = []
i = 1
# Iterate through files in the directory
for filename in cbl_files:
    cobol_code = read_cobol_file(filename)
    if cobol_code is not None:
        # Generate JSON output
        br_json = get_raw_text_gemini(cobol_code, code_systemMessage)  
        # Append data to the list
        data_list.append({'Cobol_code': cobol_code, 'BR_json': br_json})
        print(f"Done with {i} files out of {len(cbl_files)}")
        i += 1
    else:
        print(f"Skipped {filename} as it exceeds 10KB")

# Create DataFrame
df = pd.DataFrame(data_list)

# Save DataFrame to CSV
df.to_csv('dataset_cbl.csv', index=False)
# Out:
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\abrignoli_COBSOFT\CS00000F.cbl as it exceeds 10KB
# Done with 1 files out of 562
# Done with 2 files out of 562
# Done with 3 files out of 562
# Done with 4 files out of 562
# Done with 5 files out of 562
# Done with 6 files out of 562
# Done with 7 files out of 562
# Done with 8 files out of 562
# Done with 9 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\abrignoli_COBSOFT\CS00005S.cbl as it exceeds 10KB
# Done with 10 files out of 562
# Done with 11 files out of 562
# Done with 12 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\abrignoli_COBSOFT\CS00103S.cbl as it exceeds 10KB
# Done with 13 files out of 562
# Done with 14 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\abrignoli_COBSOFT\CS00106S.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\abrignoli_COBSOFT\CS10001C.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\abrignoli_COBSOFT\CS10001P.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\abrignoli_COBSOFT\CS10002C.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\abrignoli_COBSOFT\CS10003C.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\abrignoli_COBSOFT\CS10004C.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\abrignoli_COBSOFT\CS10005C.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\abrignoli_COBSOFT\CS10006C.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\abrignoli_COBSOFT\CS10007C.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\abrignoli_COBSOFT\CS10008C.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\abrignoli_COBSOFT\CS10009C.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\abrignoli_COBSOFT\CS10010C.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\abrignoli_COBSOFT\CS10011C.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\abrignoli_COBSOFT\CS10012C.cbl as it exceeds 10KB
# Done with 15 files out of 562
# Done with 16 files out of 562
# Done with 17 files out of 562
# Done with 18 files out of 562
# Done with 19 files out of 562
# Done with 20 files out of 562
# Done with 21 files out of 562
# Done with 22 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\abrignoli_COBSOFT\CS20003C.cbl as it exceeds 10KB
# Done with 23 files out of 562
# Done with 24 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\abrignoli_COBSOFT\CS30003C.cbl as it exceeds 10KB
# Done with 25 files out of 562
# Done with 26 files out of 562
# Done with 27 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\azac_cobol-on-wheelchair\cow.cbl as it exceeds 10KB
# Done with 28 files out of 562
# Done with 29 files out of 562
# Done with 30 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bhbandam_AZ-Legacy-Engineering\mscmtics.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bhbandam_AZ-Legacy-Engineering\wbgcash.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bhbandam_AZ-Legacy-Engineering\wbgetacc.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bhbandam_AZ-Legacy-Engineering\wbgetbal.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bhbandam_AZ-Legacy-Engineering\wbgstmt.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bhbandam_AZ-Legacy-Engineering\wbvalusr.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bhbandam_AZ-Legacy-Engineering\wbxfer.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bhbandam_AZ-Legacy-Engineering\wgrvadda.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bhbandam_AZ-Legacy-Engineering\wgrvaddc.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bhbandam_AZ-Legacy-Engineering\wgrvcusl.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bhbandam_AZ-Legacy-Engineering\wgrvgacc.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bhbandam_AZ-Legacy-Engineering\wgrvgbal.cbl as it exceeds 10KB
# Done with 31 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bhbandam_AZ-Legacy-Engineering\wgrvgdet.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bhbandam_AZ-Legacy-Engineering\wtiadda.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bhbandam_AZ-Legacy-Engineering\wtiaddc.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bhbandam_AZ-Legacy-Engineering\wtigacc.cbl as it exceeds 10KB
# Done with 32 files out of 562
# Done with 33 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bhbandam_AZ-Legacy-Engineering\wtigstmt.cbl as it exceeds 10KB
# Done with 34 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bmcsoftware_vscode-ispw\CWBWCOBX.cbl as it exceeds 10KB
# Done with 35 files out of 562
# Done with 36 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bmcsoftware_vscode-ispw\CWKTCOBX.cbl as it exceeds 10KB
# Done with 37 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bmcsoftware_vscode-ispw\CWKTDB2X.cbl as it exceeds 10KB
# Done with 38 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bmcsoftware_vscode-ispw\CWXTCOB.cbl as it exceeds 10KB
# Done with 39 files out of 562
# Done with 40 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bmcsoftware_vscode-ispw\DFSIVA34.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bmcsoftware_vscode-ispw\DFSIVP34.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\bmcsoftware_vscode-ispw\IB4OP01.cbl as it exceeds 10KB
# Done with 41 files out of 562
# Done with 42 files out of 562
# Done with 43 files out of 562
# Done with 44 files out of 562
# Done with 45 files out of 562
# Done with 46 files out of 562
# Done with 47 files out of 562
# Done with 48 files out of 562
# Done with 49 files out of 562
# Done with 50 files out of 562
# Done with 51 files out of 562
# Done with 52 files out of 562
# Done with 53 files out of 562
# Done with 54 files out of 562
# Done with 55 files out of 562
# Done with 56 files out of 562
# Done with 57 files out of 562
# Done with 58 files out of 562
# Done with 59 files out of 562
# Done with 60 files out of 562
# Done with 61 files out of 562
# Done with 62 files out of 562
# Done with 63 files out of 562
# Done with 64 files out of 562
# Done with 65 files out of 562
# Done with 66 files out of 562
# Done with 67 files out of 562
# Done with 68 files out of 562
# Done with 69 files out of 562
# Done with 70 files out of 562
# Done with 71 files out of 562
# Done with 72 files out of 562
# Done with 73 files out of 562
# Done with 74 files out of 562
# Done with 75 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\cicsdev_cics-async-api-credit-card-application-example\ASYNCPNT.cbl as it exceeds 10KB
# Done with 76 files out of 562
# Done with 77 files out of 562
# Done with 78 files out of 562
# Done with 79 files out of 562
# Done with 80 files out of 562
# Done with 81 files out of 562
# Done with 82 files out of 562
# Done with 83 files out of 562
# Done with 84 files out of 562
# Done with 85 files out of 562
# Done with 86 files out of 562
# Done with 87 files out of 562
# Done with 88 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\cicsdev_cics-async-api-redbooks\WEBHOME.cbl as it exceeds 10KB
# Done with 89 files out of 562
# Done with 90 files out of 562
# Done with 91 files out of 562
# Done with 92 files out of 562
# Done with 93 files out of 562
# Done with 94 files out of 562
# Done with 95 files out of 562
# Done with 96 files out of 562
# Done with 97 files out of 562
# Done with 98 files out of 562
# Done with 99 files out of 562
# Done with 100 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\dasta400_mainframeadventures\PMMSSCHD.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\dasta400_mainframeadventures\PMMSSREP.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\dasta400_mainframeadventures\REPCNTRY.cbl as it exceeds 10KB
# Done with 101 files out of 562
# Done with 102 files out of 562
# Done with 103 files out of 562
# Done with 104 files out of 562
# Done with 105 files out of 562
# Done with 106 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\debinix_openjensen\cgi-add-user.cbl as it exceeds 10KB
# Done with 107 files out of 562
# Done with 108 files out of 562
# Done with 109 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\debinix_openjensen\cgi-edit-user.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\debinix_openjensen\cgi-list-betygalla.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\debinix_openjensen\cgi-list-betygelev.cbl as it exceeds 10KB
# Done with 110 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\debinix_openjensen\cgi-list-users.cbl as it exceeds 10KB
# Done with 111 files out of 562
# Done with 112 files out of 562
# Done with 113 files out of 562
# Done with 114 files out of 562
# Done with 115 files out of 562
# Done with 116 files out of 562
# Done with 117 files out of 562
# Done with 118 files out of 562
# Done with 119 files out of 562
# Done with 120 files out of 562
# Done with 121 files out of 562
# Done with 122 files out of 562
# Done with 123 files out of 562
# Done with 124 files out of 562
# Done with 125 files out of 562
# Done with 126 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\debinix_pbs\customermenu.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\debinix_pbs\pbs.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\debinix_pbs\ReadBG.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\debinix_pbs\Readfile.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\debinix_pbs\servicemenu.cbl as it exceeds 10KB
# Done with 127 files out of 562
# Done with 128 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\debinix_pbs\subinv.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\debinix_pbs\subinv2.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\debinix_pbs\submit-invoices.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\DoHITB_CryptoCobol\AESCORE.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\DoHITB_CryptoCobol\AESGEN.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\DoHITB_CryptoCobol\AESMAIN.cbl as it exceeds 10KB
# Done with 129 files out of 562
# Done with 130 files out of 562
# Done with 131 files out of 562
# Done with 132 files out of 562
# Done with 133 files out of 562
# Done with 134 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\DoHITB_CryptoCobol\SHA1HEX.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\DoHITB_CryptoCobol\SHA512.cbl as it exceeds 10KB
# Done with 135 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\edge05_MortgageApplication2\epscsmrd.cbl as it exceeds 10KB
# Done with 136 files out of 562
# Done with 137 files out of 562
# Done with 138 files out of 562
# Done with 139 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\federico-priolo_GuiCOBOL\agarcob.cbl as it exceeds 10KB
# Done with 140 files out of 562
# Done with 141 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\federico-priolo_GuiCOBOL\guicobol.cbl as it exceeds 10KB
# Done with 142 files out of 562
# Done with 143 files out of 562
# Done with 144 files out of 562
# Done with 145 files out of 562
# Done with 146 files out of 562
# Done with 147 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\gnaresh2328_sonarqube\Custmnt2.cbl as it exceeds 10KB
# Done with 148 files out of 562
# Done with 149 files out of 562
# Done with 150 files out of 562
# Done with 151 files out of 562
# Done with 152 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\ibmdbbdev_Samples\epscsmrd.cbl as it exceeds 10KB
# Done with 153 files out of 562
# Done with 154 files out of 562
# Done with 155 files out of 562
# Done with 156 files out of 562
# Done with 157 files out of 562
# Done with 158 files out of 562
# Done with 159 files out of 562
# Done with 160 files out of 562
# Done with 161 files out of 562
# Done with 162 files out of 562
# Done with 163 files out of 562
# Done with 164 files out of 562
# Done with 165 files out of 562
# Done with 166 files out of 562
# Done with 167 files out of 562
# Done with 168 files out of 562
# Done with 169 files out of 562
# Done with 170 files out of 562
# Done with 171 files out of 562
# Done with 172 files out of 562
# Done with 173 files out of 562
# Done with 174 files out of 562
# Done with 175 files out of 562
# Done with 176 files out of 562
# Done with 177 files out of 562
# Done with 178 files out of 562
# Done with 179 files out of 562
# Done with 180 files out of 562
# Done with 181 files out of 562
# Done with 182 files out of 562
# Done with 183 files out of 562
# Done with 184 files out of 562
# Done with 185 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\IBM_example-health-apis\HCMRESTW.cbl as it exceeds 10KB
# Done with 186 files out of 562
# Done with 187 files out of 562
# Done with 188 files out of 562
# Done with 189 files out of 562
# Done with 190 files out of 562
# Done with 191 files out of 562
# Done with 192 files out of 562
# Done with 193 files out of 562
# Done with 194 files out of 562
# Done with 195 files out of 562
# Done with 196 files out of 562
# Done with 197 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\IBM_idz-utilities\GAM0VDB.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\IBM_idz-utilities\GAM0VII.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\IBM_idz-utilities\GAM0VMI.cbl as it exceeds 10KB
# Done with 198 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\IBM_idz-utilities\GAM0VSI.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\IBM_zOS-Client-Web-Enablement-Toolkit\HWTHXCB1.cbl as it exceeds 10KB
# Done with 199 files out of 562
# Done with 200 files out of 562
# Done with 201 files out of 562
# Done with 202 files out of 562
# Done with 203 files out of 562
# Done with 204 files out of 562
# Done with 205 files out of 562
# Done with 206 files out of 562
# Done with 207 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\lauryndbrown_Cisp\tokenizer.cbl as it exceeds 10KB
# Done with 208 files out of 562
# Done with 209 files out of 562
# Done with 210 files out of 562
# Done with 211 files out of 562
# Done with 212 files out of 562
# Done with 213 files out of 562
# Done with 214 files out of 562
# Done with 215 files out of 562
# Done with 216 files out of 562
# Done with 217 files out of 562
# Done with 218 files out of 562
# Done with 219 files out of 562
# Done with 220 files out of 562
# Done with 221 files out of 562
# Done with 222 files out of 562
# Done with 223 files out of 562
# Done with 224 files out of 562
# Done with 225 files out of 562
# Done with 226 files out of 562
# Done with 227 files out of 562
# Done with 228 files out of 562
# Done with 229 files out of 562
# Done with 230 files out of 562
# Done with 231 files out of 562
# Done with 232 files out of 562
# Done with 233 files out of 562
# Done with 234 files out of 562
# Done with 235 files out of 562
# Done with 236 files out of 562
# Done with 237 files out of 562
# Done with 238 files out of 562
# Done with 239 files out of 562
# Done with 240 files out of 562
# Done with 241 files out of 562
# Done with 242 files out of 562
# Done with 243 files out of 562
# Done with 244 files out of 562
# Done with 245 files out of 562
# Done with 246 files out of 562
# Done with 247 files out of 562
# Done with 248 files out of 562
# Done with 249 files out of 562
# Done with 250 files out of 562
# Done with 251 files out of 562
# Done with 252 files out of 562
# Done with 253 files out of 562
# Done with 254 files out of 562
# Done with 255 files out of 562
# Done with 256 files out of 562
# Done with 257 files out of 562
# Done with 258 files out of 562
# Done with 259 files out of 562
# Done with 260 files out of 562
# Done with 261 files out of 562
# Done with 262 files out of 562
# Done with 263 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\martinluc_Cobol_spreadSheet\Cob_CallTables_1of2.cbl as it exceeds 10KB
# Done with 264 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\mikebharris_BAMS\bams.cbl as it exceeds 10KB
# Done with 265 files out of 562
# Done with 266 files out of 562
# Done with 267 files out of 562
# Done with 268 files out of 562
# Done with 269 files out of 562
# Done with 270 files out of 562
# Done with 271 files out of 562
# Done with 272 files out of 562
# Done with 273 files out of 562
# Done with 274 files out of 562
# Done with 275 files out of 562
# Done with 276 files out of 562
# Done with 277 files out of 562
# Done with 278 files out of 562
# Done with 279 files out of 562
# Done with 280 files out of 562
# Done with 281 files out of 562
# Done with 282 files out of 562
# Done with 283 files out of 562
# Done with 284 files out of 562
# Done with 285 files out of 562
# Done with 286 files out of 562
# Done with 287 files out of 562
# Done with 288 files out of 562
# Done with 289 files out of 562
# Done with 290 files out of 562
# Done with 291 files out of 562
# Done with 292 files out of 562
# Done with 293 files out of 562
# Done with 294 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\neopragma_cobol-unit-test\ZUTZCPC.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\OlegKunitsyn_ecblunit\ecblunit.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\OlegKunitsyn_ecblunit\tests.cbl as it exceeds 10KB
# Done with 295 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\OlegKunitsyn_gcblunit\gcblunit.cbl as it exceeds 10KB
# Done with 296 files out of 562
# Done with 297 files out of 562
# Done with 298 files out of 562
# Done with 299 files out of 562
# Done with 300 files out of 562
# Done with 301 files out of 562
# Done with 302 files out of 562
# Done with 303 files out of 562
# Done with 304 files out of 562
# Done with 305 files out of 562
# Done with 306 files out of 562
# Done with 307 files out of 562
# Done with 308 files out of 562
# Done with 309 files out of 562
# Done with 310 files out of 562
# Done with 311 files out of 562
# Done with 312 files out of 562
# Done with 313 files out of 562
# Done with 314 files out of 562
# Done with 315 files out of 562
# Done with 316 files out of 562
# Done with 317 files out of 562
# Done with 318 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\SebastianRzk_gradle-cobol-plugin-unittest-extension\ZUTZCPC.CBL as it exceeds 10KB
# Done with 319 files out of 562
# Done with 320 files out of 562
# Done with 321 files out of 562
# Done with 322 files out of 562
# Done with 323 files out of 562
# Done with 324 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\shamrice_COBOL-Roguelike\crl_editor.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\shamrice_COBOL-Roguelike\crl_engine.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\shamrice_COBOL-Roguelike\crl_item_creator.cbl as it exceeds 10KB
# Done with 325 files out of 562
# Done with 326 files out of 562
# Done with 327 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\shamrice_COBOL-Roguelike\draw_dynamic_screen_data.cbl as it exceeds 10KB
# Done with 328 files out of 562
# Done with 329 files out of 562
# Done with 330 files out of 562
# Done with 331 files out of 562
# Done with 332 files out of 562
# Done with 333 files out of 562
# Done with 334 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\shamrice_COBOL-RSS-Reader\application_configurator.cbl as it exceeds 10KB
# Done with 335 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\shamrice_COBOL-RSS-Reader\crssr.cbl as it exceeds 10KB
# Done with 336 files out of 562
# Done with 337 files out of 562
# Done with 338 files out of 562
# Done with 339 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\shamrice_COBOL-RSS-Reader\rss_parser.cbl as it exceeds 10KB
# Done with 340 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\shamrice_COBOL-RSS-Reader\rss_reader_configuration.cbl as it exceeds 10KB
# Done with 341 files out of 562
# Done with 342 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\shamrice_COBOL-RSS-Reader\rss_reader_help.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\shamrice_COBOL-RSS-Reader\rss_reader_menu.cbl as it exceeds 10KB
# Done with 343 files out of 562
# Done with 344 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\shamrice_COBOL-RSS-Reader\rss_report_writer.cbl as it exceeds 10KB
# Done with 345 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\ShaunLawrie_TicTacTOBOL\TicTacTOBOL.cbl as it exceeds 10KB
# Done with 346 files out of 562
# Done with 347 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\thinkinglabs_cobol-fizzbuzz-kata\ZUTZCPC.CBL as it exceeds 10KB
# Done with 348 files out of 562
# Done with 349 files out of 562
# Done with 350 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\tylerbro93_COBOL-MERGE-AND-SORTED-WAREHOUSE-INVENTORY-SALES\PROJECT4.cbl as it exceeds 10KB
# Done with 351 files out of 562
# Done with 352 files out of 562
# Done with 353 files out of 562
# Done with 354 files out of 562
# Done with 355 files out of 562
# Done with 356 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\ve3wwg_cobcurses\COBCKEYS.cbl as it exceeds 10KB
# Done with 357 files out of 562
# Done with 358 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\ve3wwg_cobcurses\COBCURSG.cbl as it exceeds 10KB
# Done with 359 files out of 562
# Done with 360 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\ve3wwg_cobcurses\COBCURSQ.cbl as it exceeds 10KB
# Done with 361 files out of 562
# Done with 362 files out of 562
# Done with 363 files out of 562
# Done with 364 files out of 562
# Done with 365 files out of 562
# Done with 366 files out of 562
# Done with 367 files out of 562
# Done with 368 files out of 562
# Done with 369 files out of 562
# Done with 370 files out of 562
# Done with 371 files out of 562
# Done with 372 files out of 562
# Done with 373 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\walmartlabs_zECS\ECS001.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\walmartlabs_zECS\ZECS000.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\walmartlabs_zECS\ZECS001.cbl as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\walmartlabs_zECS\ZECS003.cbl as it exceeds 10KB
# Done with 374 files out of 562
# Done with 375 files out of 562
# Done with 376 files out of 562
# Done with 377 files out of 562
# Done with 378 files out of 562
# Done with 379 files out of 562
# Done with 380 files out of 562
# Done with 381 files out of 562
# Done with 382 files out of 562
# Done with 383 files out of 562
# Done with 384 files out of 562
# Done with 385 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\PROGRAM.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTADD1.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTADD2.CBL as it exceeds 10KB
# Done with 386 files out of 562
# Done with 387 files out of 562
# Done with 388 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTBEC5.CBL as it exceeds 10KB
# Done with 389 files out of 562
# Done with 390 files out of 562
# Done with 391 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTBEC9.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTBFP1.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTBMC1.CBL as it exceeds 10KB
# Done with 392 files out of 562
# Done with 393 files out of 562
# Done with 394 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTCMP1.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTCMP2.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTCMP3.CBL as it exceeds 10KB
# Done with 395 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTCMP5.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTCMP6.CBL as it exceeds 10KB
# Done with 396 files out of 562
# Done with 397 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTDFP1.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTDIV1.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTDIV2.CBL as it exceeds 10KB
# Done with 398 files out of 562
# Done with 399 files out of 562
# Done with 400 files out of 562
# Done with 401 files out of 562
# Done with 402 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTHFP1.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTICC1.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTIF1.CBL as it exceeds 10KB
# Done with 403 files out of 562
# Done with 404 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTINT1.CBL as it exceeds 10KB
# Done with 405 files out of 562
# Done with 406 files out of 562
# Done with 407 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTMOV3.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTMPY1.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTMPY2.CBL as it exceeds 10KB
# Done with 408 files out of 562
# Done with 409 files out of 562
# Done with 410 files out of 562
# Done with 411 files out of 562
# Done with 412 files out of 562
# Done with 413 files out of 562
# Done with 414 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTSUB1.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTSUB2.CBL as it exceeds 10KB
# Done with 415 files out of 562
# Done with 416 files out of 562
# Done with 417 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTVSC1.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTVSC2.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\TESTVSC3.CBL as it exceeds 10KB
# Done with 418 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\U1.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\U2.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\U4.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\U6.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\U6B.CBL as it exceeds 10KB
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\z390development_z390\UPROGRAM.CBL as it exceeds 10KB
# Done with 419 files out of 562
# Skipped C:/Users/chira/OneDrive/Documents/Research Work/COBOL/COBREX_CLI/COBREX_CLI/COBOL_Files\zosconnect_zosconnect-sample-cobol-apirequester\claimci0.cbl as it exceeds 10KB
# Done with 420 files out of 562
# Done with 421 files out of 562
